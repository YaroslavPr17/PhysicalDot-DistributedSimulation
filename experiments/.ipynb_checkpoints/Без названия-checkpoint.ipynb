# %%
# %cd ../
# Out:
# /home/pristalovya/Inter/Programming/DC/PhysicalDot-DistributedSimulation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(30,20)})
sns.set (font_scale=3)

# %%
stat = pd.read_csv('./experiments/bodies/exp_data.multi_thread_repeated_threading.txt')
stat
# Out:
#      n_bodies  n_threads  n_retries  mean_comp_time  hyper_threading
# 0         120          1         21        0.526916             True
# 1         120          2         21        0.454431             True
# 2         120          4         21        0.465987             True
# 3         120          6         21        0.593191             True
# 4         120         12         21        1.016659             True
# ..        ...        ...        ...             ...              ...
# 195      2400         24         10       30.430409             True
# 196      2400         30         11       29.106956             True
# 197      2400         40         11       29.736714             True
# 198      2400         60         10       30.832672             True
# 199      2400        120          9       34.674066             True
#
# [200 rows x 5 columns]

# %%
print(stat.dtypes)
stat.n_threads = stat.n_threads.astype('category')
# Out:
# n_bodies             int64
# n_threads            int64
# n_retries            int64
# mean_comp_time     float64
# hyper_threading       bool
# dtype: object

# %%
sns.lineplot(
    stat,
    x='n_bodies',
    y='mean_comp_time',
    hue='n_threads',
    linewidth = 1.5
);

# %%
stat_pivot = pd.pivot(stat, 'n_bodies', 'n_threads', 'mean_comp_time')
stat_pivot
# Out:
# /tmp/ipykernel_1919132/3093451584.py:1: FutureWarning: In a future version of pandas all arguments of pivot except for the argument 'data' will be keyword-only.
#   stat_pivot = pd.pivot(stat, 'n_bodies', 'n_threads', 'mean_comp_time')
# n_threads           1          2          4          6         12         24  \
# n_bodies
# 120          0.526916   0.454431   0.465987   0.593191   1.016659   1.896535
# 240          1.497445   1.074455   0.908224   1.010113   1.351270   2.138176
# 360          2.867456   1.930916   1.461090   1.447588   1.755203   2.442368
# 480          4.882682   3.014842   2.161921   1.980148   2.235580   2.881689
# 600          7.504984   4.278048   2.972073   2.585212   2.781040   3.453066
# 720         10.653068   5.988738   4.003718   3.381844   3.469350   4.209355
# 840         14.902065   8.577927   5.297023   4.362632   4.258567   5.164465
# 960         20.543235  11.658066   6.985856   5.633553   5.179667   6.142458
# 1080        27.154531  15.279922   8.969464   7.037925   6.193784   7.277200
# 1200        34.519132  19.175519  11.375064   8.584283   7.254570   8.561473
# 1320        41.837706  23.256864  13.694139  10.219448   8.476052   9.879965
# 1440        49.666227  27.493809  16.036370  11.929300   9.776191  11.405397
# 1560        58.428860  32.242244  18.724937  13.819802  11.197071  13.025805
# 1680        67.984166  37.720580  21.575198  15.957028  12.848200  14.705979
# 1800        77.067866  43.293336  24.637689  18.234204  15.283438  17.110859
# 1920        88.728449  48.892074  27.934517  20.339200  16.382745  18.441709
# 2040       101.010943  55.626130  31.388692  23.093451  19.115211  21.315803
# 2160       112.534688  61.194767  34.614801  25.899441  23.894324  24.535337
# 2280       125.108388  67.821863  38.656299  33.527430  33.627616  30.261970
# 2400       136.329255  74.953934  42.334714  34.423033  34.479397  30.430409
#
# n_threads         30         40         60        120
# n_bodies
# 120         2.289448   3.001967   4.495042   9.081855
# 240         2.588074   3.292371   4.826344   9.449035
# 360         2.838252   3.511401   4.989464   9.574489
# 480         3.282609   3.926334   5.266215   9.833177
# 600         3.761127   4.403482   5.771696  10.128805
# 720         4.481182   5.046672   6.351936  10.656559
# 840         5.389112   5.857364   7.180896  11.261431
# 960         6.485519   6.974716   8.096821  11.885097
# 1080        7.634803   8.095881   9.132948  12.716018
# 1200        8.891909   9.256606  10.351157  14.085869
# 1320       10.305750  10.643434  11.789563  15.324452
# 1440       11.867095  12.037036  13.202135  16.497246
# 1560       13.334799  13.485621  14.781706  17.980807
# 1680       14.886579  15.251675  16.406361  19.801675
# 1800       17.488919  17.735859  18.866921  21.989249
# 1920       18.636865  19.182412  20.099357  23.813130
# 2040       22.036295  22.239827  23.253460  26.986426
# 2160       24.643103  24.844408  26.201233  30.149008
# 2280       28.931040  29.344487  29.959029  33.265095
# 2400       29.106956  29.736714  30.832672  34.674066

# %%
for n_th in stat_pivot.index:
    sns.lineplot(
        stat_pivot.loc[n_th, :]
    )
